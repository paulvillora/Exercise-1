# %%
ice_cream_rating = 5
sleeping_rating = 10

# %%
first_name = input("Input First Name:")
last_name = input("Input Last Name:")
# Out:
# Input First Name: Paul Joshua
# Input Last Name: Villora

# %%
import math

# %%
happiness_rating = (ice_cream_rating + sleeping_rating)/2
print(happiness_rating)
# Out:
# 7.5

# %%
type(ice_cream_rating)
# Out:
# int

# %%
type(sleeping_rating)
# Out:
# int

# %%
type(happiness_rating)
# Out:
# float

# %%
print(type(ice_cream_rating))
print(type(sleeping_rating))
print(type(happiness_rating))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Question 1: Did all of the data types make sense?
#
# Answer: Yes. Since the ice cream and sleeping ratings were numerical inputs, I think it makes sense that it becomes an integer (or int) especially if it's going to be used for quantification. Same goes to the happiness rating, howevr now it's a float because it has a decimal value.
#
#
# Question 2: Were there any data types that were different than you expected?
#
# Answer: None

# %%
print("My name is", first_name, "and I give eating ice cream a score of", ice_cream_rating, "out of 10!")
print("I am", first_name, last_name, "and my sleeping enjoyment rating is", sleeping_rating, "/ 10!")
print("Based on the factors above, my happiness rating is", happiness_rating, "out of 10, or", happiness_rating * 100 / 10, "%!")
# Out:
# My name is Paul Joshua and I give eating ice cream a score of 5 out of 10!
# I am Paul Joshua Villora and my sleeping enjoyment rating is 10 / 10!
# Based on the factors above, my happiness rating is 7.5 out of 10, or 75.0 %!
